# %%
# !pip install pymongo
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\smitp\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
# !pip install dnspython
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\smitp\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import json
from pymongo import MongoClient

try:
    # ---- LOAD THE JSON FILE ----
    with open("recommendations.json", "r", encoding="utf-8") as f:
        data = json.load(f)    # data = list of 700+ records

    # ---- CONNECT TO MONGODB ----
    client = MongoClient("mongodb+srv://smitp_db_user:MtkZ4JBAjq7A2RmU@cluster0.z7e5akd.mongodb.net/")
    db = client["CardEngineDB"]              # choose any name
    collection = db["Recommendations"]       # choose any name

    # ---- INSERT ALL DOCUMENTS ----
    if isinstance(data, list):
        collection.insert_many(data)
    else:
        collection.insert_one(data)

    print("✔ JSON uploaded to MongoDB successfully!")

except Exception as e:
    print("❌ Error uploading JSON:", e)
# Out:
# ✔ JSON uploaded to MongoDB successfully!
