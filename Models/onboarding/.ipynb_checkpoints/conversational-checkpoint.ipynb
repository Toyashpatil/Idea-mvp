# %%
# !pip install --upgrade "optree>=0.13.0"
# Out:
# Collecting optree>=0.13.0
#   Downloading optree-0.14.1-cp311-cp311-win_amd64.whl.metadata (50 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\python\lib\site-packages (from optree>=0.13.0) (4.12.2)
# Downloading optree-0.14.1-cp311-cp311-win_amd64.whl (305 kB)
# Installing collected packages: optree
#   Attempting uninstall: optree
#     Found existing installation: optree 0.12.1
#     Uninstalling optree-0.12.1:
#       Successfully uninstalled optree-0.12.1
# Successfully installed optree-0.14.1
#   WARNING: Failed to remove contents in a temporary directory 'D:\Python\Lib\site-packages\~ptree'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, set_seed

class ConversationalLLM:
    """
    Wraps an instruction-tuned encoder-decoder model (Flan-T5) for conversational use.
    """

    def __init__(self, model_name: str = "google/flan-t5-small", max_length: int = 128, temperature: float = 0.7):
        self.model_name = model_name
        self.max_length = max_length
        self.temperature = temperature
        
        # Set random seed for reproducibility (optional)
        set_seed(42)

        # Load tokenizer
        print(f"Loading tokenizer for {model_name}...")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
        
        # Load model
        print(f"Loading model {model_name}...")
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
        
        # Auto-detect device
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")
        self.model.to(self.device)

    def generate_response(self, instruction: str, conversation_history: str = "") -> str:
        """
        Generate a response based on the current conversation context + new instruction.

        For an instruction-tuned model, we typically provide the key instruction
        or user request as the entire "prompt," and keep the conversation history
        minimal or summarized if needed.
        """

        # We can craft a combined prompt with context
        # e.g. "CONTEXT:\n{conversation_history}\n\nUSER'S TASK:\n{instruction}"
        prompt = f"CONTEXT:\n{conversation_history}\n\nUSER'S TASK:\n{instruction}\n"

        inputs = self.tokenizer(prompt, return_tensors="pt").to(self.device)

        with torch.no_grad():
            output_ids = self.model.generate(
                **inputs,
                max_length=self.max_length,
                temperature=self.temperature,
                top_p=0.9,
                do_sample=True,
                num_return_sequences=1
            )

        generated_text = self.tokenizer.decode(output_ids[0], skip_special_tokens=True)

        return generated_text.strip()

# %%
import torch
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, set_seed

# Define the ConversationalLLM class for Flan-T5
class ConversationalLLM:
    """
    Wraps an instruction-tuned encoder-decoder model (Flan-T5) for conversational use.
    """
    def __init__(self, model_name: str = "google/flan-t5-base", max_length: int = 128, temperature: float = 0.7):
        self.model_name = model_name
        self.max_length = max_length
        self.temperature = temperature
        
        # Set random seed for reproducibility (optional)
        set_seed(42)

        # Load tokenizer
        print(f"Loading tokenizer for {model_name}...")
        self.tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)
        
        # Load model
        print(f"Loading model {model_name}...")
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
        
        # Auto-detect device
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        print(f"Using device: {self.device}")
        self.model.to(self.device)

    def generate_response(self, instruction: str, conversation_history: str = "") -> str:
        """
        Generate a response based on the current conversation context + new instruction.
        """
        prompt = f"CONTEXT:\n{conversation_history}\n\nUSER'S TASK:\n{instruction}\n"
        inputs = self.tokenizer(prompt, return_tensors="pt").to(self.device)
        with torch.no_grad():
            output_ids = self.model.generate(
                **inputs,
                max_length=self.max_length,
                temperature=self.temperature,
                top_p=0.9,
                do_sample=True,
                num_return_sequences=1
            )
        generated_text = self.tokenizer.decode(output_ids[0], skip_special_tokens=True)
        return generated_text.strip()

# Define the ConversationManager class
class ConversationManager:
    """
    Manages the conversation flow and user onboarding questions.
    """
    def __init__(self):
        self.required_questions = [
            "Please provide your full legal name.",
            "What is your primary phone number?",
            "What is your email address?",
            "Do you anticipate frequent international transactions?",
        ]
        self.current_question_index = 0
        self.answers = {}
        self.conversation_history = ""

    def get_next_question(self):
        """
        Returns the next question in the onboarding flow.
        If we've reached the end, returns None.
        """
        if self.current_question_index < len(self.required_questions):
            return self.required_questions[self.current_question_index]
        return None

    def record_answer(self, question: str, answer: str):
        """
        Stores the user's answer and updates the conversation history.
        """
        self.answers[question] = answer
        self.conversation_history += f"\nUser: {answer}"

    def advance_flow(self):
        """
        Moves to the next question.
        """
        self.current_question_index += 1

    def is_onboarding_complete(self) -> bool:
        return self.current_question_index >= len(self.required_questions)

# --- Conversation Loop ---
# Instantiate the LLM (Flan-T5) and the ConversationManager
llm = ConversationalLLM(model_name="google/flan-t5-base", max_length=128, temperature=0.3)
conv_manager = ConversationManager()

# System instructions to provide context to the model
system_instructions = (
    "You are an AI assistant helping a user with bank onboarding. "
    "Gather their personal and account usage details. Be concise and user-friendly."
)

print("System: Onboarding conversation started.")
print("---------------------------------------")

while not conv_manager.is_onboarding_complete():
    # 1. Retrieve the next question
    question = conv_manager.get_next_question()
    if question is None:
        break
    
    # 2. Use Flan-T5 to rephrase the question (optional)
    conversation_so_far = f"System: {system_instructions}\n{conv_manager.conversation_history}"
    rephrased_question = llm.generate_response(
        instruction=f"Please rephrase this question in a friendly manner: {question}",
        conversation_history=conversation_so_far
    )
    
    # Print the AI-generated question
    print("Assistant (Question):", rephrased_question)
    
    # Capture user input in the notebook
    user_input = input("User (Answer): ")
    
    # Record the answer
    conv_manager.record_answer(question, user_input)
    
    # Advance to the next question
    conv_manager.advance_flow()

print("\nAssistant: Thank you! We have all the information we need for onboarding.")
print("Your collected answers:", conv_manager.answers)
# Out:
# Loading tokenizer for google/flan-t5-base...
# Loading model google/flan-t5-base...
# Using device: cpu
# System: Onboarding conversation started.
# ---------------------------------------
# Assistant (Question): Your full legal name is jimmy taylor
# User (Answer):  yash
# Assistant (Question): 0
